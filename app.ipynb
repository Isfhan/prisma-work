# %% [markdown]
# # Clone github repo

# %%
# %tensorflow_version 1.x
# !git clone https://github.com/Isfhan/prisma-work.git
# !cp -r prisma-work/NeuralStyleTransfer .
# !rm -r prisma-work
# !rm -r sample_data/
# Out:
# Cloning into 'prisma-work'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 24 (delta 2), reused 15 (delta 0), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5a64fe9c-85ef-4fea-8b1b-1918eb6b5947" name="files[]" multiple disabled />
#      <output id="result-5a64fe9c-85ef-4fea-8b1b-1918eb6b5947">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 16265511_1040183206128549_2157389788216303346_n.jpg to 16265511_1040183206128549_2157389788216303346_n.jpg
# Saving band+clip+art.gif to band+clip+art.gif
# ...

# %%
content_img = "1.jpg" 
style_img = "2.gif"

IMAGE_HEIGHT = 960
IMAGE_WIDTH = 720

ITERATION = 200

# %% [markdown]
# # setting images path

# %%
content_image_path = "/content/"+content_img
style_image_path = "/content/"+style_img

# %% [markdown]
# # Importing matplotlib for showing image

# %%
import matplotlib.pyplot as plt
c_image = plt.imread(content_image_path)
s_image = plt.imread(style_image_path)

# %%
print("Content Image of size (height, width) => {0}".format(c_image.shape[:-1]))
plt.imshow(c_image)
# Out:
# Content Image of size (height, width) => (960, 720)

# %%
print("Style Image of size (height, width) => {0}".format(s_image.shape[:-1]))
plt.imshow(s_image)
# Out:
# Style Image of size (height, width) => (187, 189)

# %% [markdown]
# # Importing Neural Style Transfer

# %%
from NeuralStyleTransfer import implementNTS as NST

NST.setImageDim(IMAGE_WIDTH,IMAGE_HEIGHT)

NST.run(ITERATION, style_image=style_image_path, content_image=content_image_path)
# Out:
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:318: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# downloading...
# *done*
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:204: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:333: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/NeuralStyleTransfer/implementNTS.py:355: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !ls NeuralStyleTransfer/output/
# Out:
# 100.jpg  200.jpg  generated_image.jpg  oimage

# %% [markdown]
# # Showing generated image

# %%
generated_image = "/content/NeuralStyleTransfer/output/generated_image.jpg"
image = plt.imread(generated_image)
plt.imshow(image)

# %%
files.download("NeuralStyleTransfer/output/generated_image.jpg")
